# %% [markdown]
# # Installation

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

import math
import pandas as pd
import numpy as np
from IPython.display import display
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Loading

# %%
data = pd.read_csv('NSE-Tata-Chem.csv')
dataset_train=data.iloc[0:930,1:2]
dataset_test=data.iloc[930:,1:2]
training_set = data.iloc[0:930, 3:4].values
testing_set=data.iloc[930:,3:4].values
data.head()
# Out:
#          Date     Open     High      Low     Last    Close  \
# 0  2024-06-12  1110.90  1135.00  1097.00  1123.60  1111.40
# 1  2024-06-11  1081.10  1120.95  1073.40  1111.40  1086.00
# 2  2024-06-10  1064.95  1097.70  1060.00  1086.00  1056.15
# 3  2024-06-07  1028.90  1061.60  1017.95  1056.15  1063.35
# 4  2024-06-06  1046.95  1067.00  1045.00  1063.35  1043.10
#
#    Total Trade Quantity  Turnover (Cr)
# 0                 93150     403.688819
# 1                 95841     381.099581
# 2                 66806     266.159937
# 3                 65954     258.761442
# 4                 32991      90.913203

# %%
data.drop('Last', axis=1, inplace=True)
data.drop('Total Trade Quantity', axis=1, inplace=True)
data.drop('Turnover (Cr)', axis=1, inplace=True)
print(data.head())
data.to_csv('tata_preprocessed.csv',index= False)
data = data.iloc[::-1]
# Out:
#          Date     Open     High      Low    Close
# 0  2024-06-12  1110.90  1135.00  1097.00  1111.40
# 1  2024-06-11  1081.10  1120.95  1073.40  1086.00
# 2  2024-06-10  1064.95  1097.70  1060.00  1056.15
# 3  2024-06-07  1028.90  1061.60  1017.95  1063.35
# 4  2024-06-06  1046.95  1067.00  1045.00  1043.10

# %%
plt.figure(figsize = (19,10))
plt.plot(range(data.shape[0]),(data['Open']))
plt.xticks(range(0,data.shape[0],500),data['Date'].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=19)
plt.ylabel('Open Price',fontsize=19)
plt.show()

# %% [markdown]
# # Pre-Processing

# %%
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(10,930):
    X_train.append(training_set_scaled[i-10:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# # Prediction Using Deep Learning

# %%
regressor = Sequential()

regressor.add(LSTM(units = 80, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.1))

regressor.add(LSTM(units = 55, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 55, return_sequences = True))
regressor.add(Dropout(0.1))

regressor.add(LSTM(units = 80))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs = 200, batch_size = 128)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 8s 69ms/step - loss: 0.3064
# Epoch 2/200
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0501
# Epoch 3/200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0388
# Epoch 4/200
# 8/8 [==============================] - 1s 121ms/step - loss: 0.0215
# Epoch 5/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0172
# Epoch 6/200
# 8/8 [==============================] - 1s 116ms/step - loss: 0.0141
# Epoch 7/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0115
# Epoch 8/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0094
# Epoch 9/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.0080
# Epoch 10/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0072
# Epoch 11/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0065
# Epoch 12/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0065
# Epoch 13/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0063
# Epoch 14/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0064
# Epoch 15/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0061
# Epoch 16/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0056
# Epoch 17/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0062
# Epoch 18/200
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0064
# Epoch 19/200
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0061
# Epoch 20/200
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0062
# Epoch 21/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0057
# Epoch 22/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0059
# Epoch 23/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0056
# Epoch 24/200
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0057
# Epoch 25/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0060
# Epoch 26/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0054
# Epoch 27/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0059
# Epoch 28/200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0054
# Epoch 29/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0055
# Epoch 30/200
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0057
# Epoch 31/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0053
# Epoch 32/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0057
# Epoch 33/200
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0052
# Epoch 34/200
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0059
# Epoch 35/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0053
# Epoch 36/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0049
# Epoch 37/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0055
# Epoch 38/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0059
# Epoch 39/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0055
# Epoch 40/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0056
# Epoch 41/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0052
# Epoch 42/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0055
# Epoch 43/200
# 8/8 [==============================] - 1s 61ms/step - loss: 0.0055
# Epoch 44/200
# 8/8 [==============================] - 1s 61ms/step - loss: 0.0054
# Epoch 45/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0054
# Epoch 46/200
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0051
# Epoch 47/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0053
# Epoch 48/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0052
# Epoch 49/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0047
# Epoch 50/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0051
# Epoch 51/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0053
# Epoch 52/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0047
# Epoch 53/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0050
# Epoch 54/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0053
# Epoch 55/200
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0050
# Epoch 56/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0051
# Epoch 57/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0048
# Epoch 58/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0050
# Epoch 59/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0050
# Epoch 60/200
# 8/8 [==============================] - 1s 61ms/step - loss: 0.0050
# Epoch 61/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0049
# Epoch 62/200
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0053
# Epoch 63/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0050
# Epoch 64/200
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0050
# Epoch 65/200
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0056
# Epoch 66/200
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0060
# Epoch 67/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0051
# Epoch 68/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0052
# Epoch 69/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0053
# Epoch 70/200
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0044
# Epoch 71/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0046
# Epoch 72/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0045
# Epoch 73/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0050
# Epoch 74/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0047
# Epoch 75/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0046
# Epoch 76/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0049
# Epoch 77/200
# 8/8 [==============================] - 1s 113ms/step - loss: 0.0048
# Epoch 78/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0046
# Epoch 79/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0044
# Epoch 80/200
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0044
# Epoch 81/200
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0049
# Epoch 82/200
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0047
# Epoch 83/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0044
# Epoch 84/200
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0049
# Epoch 85/200
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0048
# Epoch 86/200
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0046
# Epoch 87/200
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0046
# Epoch 88/200
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0049
# Epoch 89/200
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0045
# Epoch 90/200
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0045
# Epoch 91/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0044
# Epoch 92/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0046
# Epoch 93/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0042
# Epoch 94/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0045
# Epoch 95/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0043
# Epoch 96/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0044
# Epoch 97/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0043
# Epoch 98/200
# 8/8 [==============================] - 1s 118ms/step - loss: 0.0047
# Epoch 99/200
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0043
# Epoch 100/200
# 8/8 [==============================] - 1s 121ms/step - loss: 0.0045
# Epoch 101/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0045
# Epoch 102/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0042
# Epoch 103/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0042
# Epoch 104/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0048
# Epoch 105/200
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0049
# Epoch 106/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0047
# Epoch 107/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0045
# Epoch 108/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0048
# Epoch 109/200
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0042
# Epoch 110/200
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0041
# Epoch 111/200
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0044
# Epoch 112/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0041
# Epoch 113/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0044
# Epoch 114/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0043
# Epoch 115/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0040
# Epoch 116/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0045
# Epoch 117/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0041
# Epoch 118/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0040
# Epoch 119/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0043
# Epoch 120/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0041
# Epoch 121/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0041
# Epoch 122/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0038
# Epoch 123/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0042
# Epoch 124/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0041
# Epoch 125/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0043
# Epoch 126/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0041
# Epoch 127/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0040
# Epoch 128/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0042
# Epoch 129/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0042
# Epoch 130/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0042
# Epoch 131/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0039
# Epoch 132/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0040
# Epoch 133/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0038
# Epoch 134/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0039
# Epoch 135/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0042
# Epoch 136/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0043
# Epoch 137/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0035
# Epoch 138/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0040
# Epoch 139/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0041
# Epoch 140/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0039
# Epoch 141/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0037
# Epoch 142/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0039
# Epoch 143/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0035
# Epoch 144/200
# 8/8 [==============================] - 1s 121ms/step - loss: 0.0041
# Epoch 145/200
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0037
# Epoch 146/200
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0038
# Epoch 147/200
# 8/8 [==============================] - 1s 59ms/step - loss: 0.0034
# Epoch 148/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0037
# Epoch 149/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0038
# Epoch 150/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0038
# Epoch 151/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0048
# Epoch 152/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0040
# Epoch 153/200
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0035
# Epoch 154/200
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0037
# Epoch 155/200
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0037
# Epoch 156/200
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0042
# Epoch 157/200
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0038
# Epoch 158/200
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0036
# Epoch 159/200
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0035
# Epoch 160/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0037
# Epoch 161/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0036
# Epoch 162/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0034
# Epoch 163/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0036
# Epoch 164/200
# 8/8 [==============================] - 1s 117ms/step - loss: 0.0033
# Epoch 165/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0036
# Epoch 166/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0038
# Epoch 167/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0035
# Epoch 168/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0038
# Epoch 169/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0038
# Epoch 170/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0035
# Epoch 171/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0033
# Epoch 172/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0039
# Epoch 173/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0033
# Epoch 174/200
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0042
# Epoch 175/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0038
# Epoch 176/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0035
# Epoch 177/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0040
# Epoch 178/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0043
# Epoch 179/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0037
# Epoch 180/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0035
# Epoch 181/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0035
# Epoch 182/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0034
# Epoch 183/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0035
# Epoch 184/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0033
# Epoch 185/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0036
# Epoch 186/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0032
# Epoch 187/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0032
# Epoch 188/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0033
# Epoch 189/200
# 8/8 [==============================] - 1s 118ms/step - loss: 0.0031
# Epoch 190/200
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0033
# Epoch 191/200
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0033
# Epoch 192/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0032
# Epoch 193/200
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0030
# Epoch 194/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0030
# Epoch 195/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0033
# Epoch 196/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0036
# Epoch 197/200
# 8/8 [==============================] - 1s 61ms/step - loss: 0.0033
# Epoch 198/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0032
# Epoch 199/200
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0032
# Epoch 200/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0027

# %%
real_stock_price = testing_set
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 10:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(10,568):
    X_test.append(inputs[i-10:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 18/18 [==============================] - 3s 12ms/step

# %% [markdown]
# # Testing

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
print(f"Shape of inputs array: {inputs.shape}")
print(f"Length of dataset_total DataFrame: {len(dataset_total)}")
print(f"Length of dataset_test DataFrame: {len(dataset_test)}")
# Out:
# Shape of inputs array: (577, 1)
# Length of dataset_total DataFrame: 1497
# Length of dataset_test DataFrame: 567

# %% [markdown]
# # **Prediction using Regression Models**

# %%
dataset = pd.read_csv('NSE-Tata-Chem.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 6)

# %%
print(X_test)
# Out:
# [[  1080.     1084.     1042.     1044.3    1080.    32673.  ]
#  [  1004.     1008.1     981.15    985.95   1003.25  29470.  ]
#  [   750.      755.      731.75    743.45    739.5  138627.  ]
#  ...
#  [   293.      299.      285.      286.05    290.55  30539.  ]
#  [   961.      962.      903.35    912.15    965.    54169.  ]
#  [   993.95   1020.      993.95   1006.25    993.95  47722.  ]]

# %%
print(X_train)
# Out:
# [[  833.65   840.     832.     834.4    829.   30617.  ]
#  [ 1057.    1065.    1032.2   1063.    1058.65 25759.  ]
#  [  972.65   978.95   964.     965.85   969.95 23783.  ]
#  ...
#  [  987.4    990.5    971.4    977.     983.45 30320.  ]
#  [  748.6    748.6    729.65   738.75   743.6  32998.  ]
#  [  315.8    321.     314.8    319.65   318.45 25425.  ]]

# %%
y_train = y_train.reshape(len(y_train),1)

# %%
print(y_train)
# Out:
# [[129.682574 ]
#  [ 62.8174438]
#  [ 82.0067664]
#  ...
#  [ 89.2752479]
#  [127.7515993]
#  [ 71.452828 ]]

# %%
y_test = y_test.reshape(len(y_test),1)

# %%
print(y_test)
# Out:
# [[  66.0825903]
#  [  95.0123666]
#  [ 647.1117064]
#  [  26.760954 ]
#  [  43.8480052]
#  [ 156.9036069]
#  [  56.3373782]
#  [ 398.7782031]
#  [  72.1163458]
#  [  85.9499871]
#  [  37.4409858]
#  [  51.9448486]
#  [ 119.6675395]
#  [  37.0899672]
#  [  13.3077599]
#  [  53.6059534]
#  [  79.4932565]
#  [  38.0369104]
#  [  98.4853393]
#  [ 112.1986441]
#  [  17.1077701]
#  [  51.1661413]
#  [  26.4300092]
#  [  38.985311 ]
#  [ 409.295386 ]
#  [ 155.5654149]
#  [  17.3893977]
#  [  67.4840267]
#  [  26.9237976]
#  [ 223.9074845]
#  [ 300.4959964]
#  [  58.7022775]
#  [ 311.3907724]
#  [ 301.1814326]
#  [  77.7220651]
#  [ 520.749932 ]
#  [  65.8390368]
#  [  24.5738736]
#  [  19.1574558]
#  [  41.0110513]
#  [ 102.2837873]
#  [ 144.4787081]
#  [  40.7323555]
#  [  29.8221505]
#  [ 527.788108 ]
#  [  23.2791682]
#  [  44.4648207]
#  [ 315.346847 ]
#  [  93.2504721]
#  [  20.7913615]
#  [ 413.6770985]
#  [ 159.346869 ]
#  [  22.2900372]
#  [  54.8206087]
#  [ 581.8718087]
#  [  32.4473874]
#  [ 310.0411838]
#  [  24.7423064]
#  [  16.7265736]
#  [ 269.2403312]
#  [ 137.531341 ]
#  [  29.7937801]
#  [ 229.7002165]
#  [  78.4516645]
#  [ 385.7058379]
#  [  34.2346698]
#  [  51.707892 ]
#  [  91.9603114]
#  [  97.2291846]
#  [  39.4390497]
#  [  92.0377227]
#  [ 335.4757811]
#  [   8.1275434]
#  [ 132.5083975]
#  [  66.5576202]
#  [  77.8936558]
#  [  47.9276994]
#  [ 219.3470229]
#  [  44.6170316]
#  [  41.1649736]
#  [  59.9495182]
#  [ 144.006578 ]
#  [  54.2222587]
#  [ 115.421946 ]
#  [  69.7046798]
#  [ 112.96835  ]
#  [ 129.6398481]
#  [1688.6995254]
#  [  66.333935 ]
#  [  98.6596586]
#  [  24.8916375]
#  [  15.1426123]
#  [  53.9641626]
#  [ 703.9261102]
#  [  50.3064512]
#  [ 276.0938957]
#  [ 114.0438916]
#  [ 178.2929827]
#  [  55.6983682]
#  [  61.0035127]
#  [  46.3646939]
#  [  79.8513238]
#  [ 104.3434573]
#  [  50.4066887]
#  [  15.9346403]
#  [ 207.7799518]
#  [ 183.4734439]
#  [  15.5454738]
#  [  26.9726093]
#  [  60.3862614]
#  [  58.8387539]
#  [ 787.4702912]
#  [  22.8861934]
#  [  73.7389396]
#  [ 422.5624406]
#  [  14.996451 ]
#  [ 878.4060363]
#  [ 107.4197446]
#  [ 224.32  283.86]
#  [  47.31   33.47]
#  [  31.14   36.56]
#  [  76.22   88.05]
#  [ 107.95   76.4 ]
#  [  14.37   14.31]
#  [ 133.91  153.46]
#  [  16.86   36.54]
#  [  23.56   18.44]
#  [  33.36   41.31]
#  [  15.97   15.04]
#  [  47.98   45.71]
#  [ 233.28  122.38]
#  [  25.47   20.1 ]
#  [ 694.35  715.28]
#  [ 115.39  101.86]
#  [  76.61   69.52]
#  [ 138.59  107.06]
#  [  45.11   32.44]
#  [  24.42   28.77]
#  [  49.2    86.04]
#  [  84.09   52.27]
#  [  44.03   48.47]
#  [  27.46   33.24]
#  [  68.55   71.67]
#  [ 116.79  149.81]
#  [  26.95   52.22]
#  [  80.13   73.49]
#  [ 435.53  331.91]
#  [  70.74   69.8 ]
#  [ 121.63   84.01]
#  [  85.82   72.55]
#  [  65.85   76.79]
#  [  45.73   46.33]
#  [  55.41   55.51]
#  [ 268.57  305.92]
#  [  36.96   37.08]
#  [ 295.17  272.95]
#  [ 196.    156.22]
#  [  50.28   52.84]
#  [  67.16   79.  ]
#  [ 106.27  135.07]
#  [  30.6    25.23]
#  [ 103.36   56.21]
#  [ 161.21  152.95]
#  [ 128.13  138.69]
#  [ 278.54  310.79]
#  [ 164.39  172.33]
#  [  43.41   38.6 ]
#  [  73.44   73.82]
#  [  94.32  113.93]
#  [  87.46  134.4 ]
#  [ 161.3   228.58]
#  [ 208.82  145.47]
#  [ 120.81   75.7 ]
#  [  62.29   55.66]
#  [  44.18   20.75]
#  [  84.13   73.  ]
#  [  35.73   49.12]
#  [  97.46   94.67]
#  [ 139.27  155.8 ]
#  [  58.18   68.84]
#  [ 361.58  337.75]
#  [  62.23   40.75]
#  [ 202.2   237.19]
#  [  33.28   33.79]
#  [  45.51   30.47]
#  [ 187.31  249.58]
#  [ 220.    235.32]
#  [  72.2    93.12]
#  [  56.37   68.79]
#  [ 201.04  179.  ]
#  [  31.56   30.09]
#  [ 172.9   195.75]
#  [  58.13   39.39]
#  [  69.38   41.25]
#  [ 116.42  166.48]
#  [  28.52   26.2 ]
#  [  34.06   24.4 ]
#  [  48.42   44.36]
#  [  59.5    65.1 ]
#  [  18.24   12.69]
#  [  82.7   120.17]
#  [ 117.03  140.67]
#  [  71.08   60.93]
#  [  29.46   17.76]
#  [ 111.38  122.73]
#  [  42.27   26.99]
#  [  48.07   28.33]
#  [  65.45   66.67]
#  [ 191.71  181.73]
#  [  73.87  118.33]
#  [ 149.09  175.6 ]
#  [  24.83   29.5 ]
#  [  84.36  125.58]
#  [  62.68   63.46]
#  [ 103.84  149.36]
#  [  42.18   40.3 ]
#  [ 456.49  403.69]
#  [  31.44   56.86]
#  [ 130.82  105.27]
#  [ 308.43  279.7 ]
#  [  39.07   29.41]
#  [ 126.1    41.48]
#  [1160.89 1089.58]
#  [  54.09   77.33]
#  [ 164.16  147.49]
#  [ 151.49  205.41]]

# %% [markdown]
# # Accuracy Of Model

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9313546739991595

# %% [markdown]
# # Price Prediction

# %%
print(regressor.predict([[1491.8,1674.3,1019.5,1432.1,1399.7,96000]]))
# Out:
# [1013.71]
